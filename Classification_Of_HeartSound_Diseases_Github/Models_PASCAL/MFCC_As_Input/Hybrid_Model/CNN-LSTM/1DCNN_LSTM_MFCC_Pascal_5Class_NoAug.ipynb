# %% [markdown]
# # 1DCNN-LSTM Heart Sound Classification (MFCC, 5-Class PASCAL)

# %% [markdown]
# ## GPU Setup

# %%
import os
import tensorflow as tf

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for gpu in physical_devices:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f'GPU Memory Growth Enabled for: {physical_devices}')
    except RuntimeError as e:
        print(f'GPU Error: {e}')
else:
    print('No GPU detected. Running on CPU.')
# Out:
# GPU Memory Growth Enabled for: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Foundation Set Up and Configuration

# %%
import os
import numpy as np
import librosa
import librosa.display
import scipy.signal as signal
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import warnings
from cryptography.utils import CryptographyDeprecationWarning

warnings.filterwarnings('ignore', category=CryptographyDeprecationWarning)
np.random.seed(42)
print('Libraries imported successfully!')

# --- CONFIGURATION 
BASE_PATH = r'C:\Users\emirh\Downloads\FYP2\Pascal'
FOLDERS = ['set_a', 'set_b']
SAMPLE_RATE = 16000
DURATION = 5
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

print(f'BASE_PATH : {BASE_PATH}')
print(f'FOLDERS   : {FOLDERS}')
print(f'SAMPLE_RATE : {SAMPLE_RATE}')
print(f'DURATION    : {DURATION}s')
# Out:
# Libraries imported successfully!
# BASE_PATH : C:\Users\emirh\Downloads\FYP2\Pascal
# FOLDERS   : ['set_a', 'set_b']
# SAMPLE_RATE : 16000
# DURATION    : 5s

# %% [markdown]
# ## Data Augmentation Functions

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    """Generates the filter coefficients."""
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = signal.butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    """Applies the Bandpass Filter (25-400Hz)."""
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = signal.lfilter(b, a, data)
    return y

def fix_duration_segmentation(data):
    """
    Apply 5-Second Fixed Segmentation.
    - If shorter than 5s: Pad with zeros.
    - If longer than 5s: Truncate.
    """
    if len(data) > SAMPLES_PER_TRACK:
        return data[:SAMPLES_PER_TRACK]
    else:
        padding = SAMPLES_PER_TRACK - len(data)
        return np.pad(data, (0, padding), 'constant')

def z_score_normalize(data):
    """
    Applies Z-Score Normalization (Standardization).
    Result has Mean = 0, Std Dev = 1.
    """
    mean = np.mean(data)
    std = np.std(data)
    if std > 0:
        return (data - mean) / std
    else:
        return data

# AUGMENTATION FUNCTIONS
def add_noise_awgn(data):
   
    sigma = np.sqrt(np.mean(data ** 2))   # RMS of the signal
    noise = np.random.normal(0, sigma, len(data))
    return data + noise

def pitch_shift(data, sampling_rate):
    
    p = np.random.randint(1, 11)          # integer in [1, 10]
    direction = np.random.choice([-1, 1]) # up or down
    n_steps = direction * p
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=n_steps)

print('Preprocessing and augmentation functions defined.')
# Out:
# Preprocessing and augmentation functions defined.

# %% [markdown]
# ## Feature Extraction (MFCC — 13 features)

# %%
def extract_features(audio_data, sample_rate):
    
    # --- MFCC EXTRACTION: 13 coefficients ---
    mfcc = librosa.feature.mfcc(
        y=audio_data,
        sr=sample_rate,
        n_mfcc=13,
        n_fft=2048,
        hop_length=512
    )

    # --- MFCC SEQUENCE FORMAT FOR CNN ---
    target_time_steps = 24

    if mfcc.shape[1] < target_time_steps:
        mfcc_padded = np.pad(
            mfcc,
            ((0, 0), (0, target_time_steps - mfcc.shape[1])),
            mode='constant'
        )
    else:
        mfcc_padded = mfcc[:, :target_time_steps]

    # TRANSPOSE (.T) -> (Time_Steps=24, MFCC_Features=13)
    mfcc_cnn_ready = mfcc_padded.T

    return mfcc_cnn_ready

print('Feature extraction function defined.')
print('Output shape per sample: (24, 13)')
# Out:
# Feature extraction function defined.
# Output shape per sample: (24, 13)

# %% [markdown]
# ## Data Preparation (MFCC — Pitch Shifting + Noise Addition Augmentation)

# %%
from tensorflow.keras.utils import to_categorical
from collections import Counter


file_paths = []
labels = []

print('Scanning folders...')
for folder in FOLDERS:
    folder_path = os.path.join(BASE_PATH, folder)
    if not os.path.exists(folder_path):
        continue

    for filename in os.listdir(folder_path):
        filename_lower = filename.lower()

        if not filename_lower.endswith('.wav') or 'unlabel' in filename_lower:
            continue

        file_path = os.path.join(folder_path, filename)

        # Label Logic 
        label = None
        if 'noisy' in filename_lower:
            continue

        if 'normal' in filename_lower:
            label = 0
        elif 'murmur' in filename_lower:
            label = 1
        elif 'extrastole' in filename_lower or 'extrasystole' in filename_lower:
            label = 2
        elif 'artifact' in filename_lower:
            label = 3
        elif 'extrahls' in filename_lower:
            label = 4

        if label is not None:
            file_paths.append(file_path)
            labels.append(label)

# Class names 
class_names = {0: 'Normal', 1: 'Murmur', 2: 'Extrasystole', 3: 'Artifact', 4: 'ExtraHLS'}

print(f'\nTotal valid files gathered: {len(labels)}')
distribution = Counter(labels)
print('-' * 30)
print('CLASS DISTRIBUTION (Before Split):')
for label_int in sorted(distribution.keys()):
    print(f' - {class_names[label_int]}: {distribution[label_int]} files')
print('-' * 30 + '\n')

# ============================================================
# 2. STRATIFIED SPLIT: 70 / 10 / 20  
# ============================================================
X_train_val_paths, X_test_paths, y_train_val_labels, y_test_labels = train_test_split(
    file_paths, labels, test_size=0.2, stratify=labels, random_state=42
)

X_train_paths, X_val_paths, y_train_labels, y_val_labels = train_test_split(
    X_train_val_paths, y_train_val_labels, test_size=0.125, stratify=y_train_val_labels, random_state=42
)

print(f'File Counts -> Train: {len(X_train_paths)}, Val: {len(X_val_paths)}, Test: {len(X_test_paths)}')

max_original_class_count = max(distribution.values()) if len(distribution) > 0 else 0
TARGET_COUNTS = {
    0: max_original_class_count,  # Normal
    1: max_original_class_count,  # Murmur
    2: max_original_class_count,  # Extrasystole
    3: max_original_class_count,  # Artifact
    4: max_original_class_count   # ExtraHLS
}

print('\nTARGET_COUNTS for training augmentation:')
for label_int in sorted(TARGET_COUNTS.keys()):
    print(f' - {class_names[label_int]:<12}: {TARGET_COUNTS[label_int]}')
# Out:
# Scanning folders...
#
# Total valid files gathered: 436
# ------------------------------
# CLASS DISTRIBUTION (Before Split):
#  - Normal: 231 files
#  - Murmur: 100 files
#  - Extrasystole: 46 files
#  - Artifact: 40 files
#  - ExtraHLS: 19 files
# ------------------------------
#
# File Counts -> Train: 304, Val: 44, Test: 88
#
# TARGET_COUNTS for training augmentation:
#  - Normal      : 231
#  - Murmur      : 231
#  - Extrasystole: 231
#  - Artifact    : 231
#  - ExtraHLS    : 231

# %% [markdown]
# ### Processing Function

# %%
def process_data_with_augmentation(X_paths, y_labels, augment=False):
    X_mfccs = []
    y_final = []

    # Store original preprocessed audio for augmentation
    audio_by_class = {0: [], 1: [], 2: [], 3: [], 4: []}

    print(f'   Processing {len(X_paths)} files (Augment={augment})...')

    # ====================================================
    # STEP 1: Process original files
    # ====================================================
    for i, fpath in enumerate(X_paths):
        try:
            y, sr = librosa.load(fpath, sr=SAMPLE_RATE, duration=DURATION)

            y = butter_bandpass_filter(y, 25, 400, sr)
            y = fix_duration_segmentation(y)
            y = z_score_normalize(y)

            current_label = y_labels[i]

            mfcc = extract_features(y, sr)

            X_mfccs.append(mfcc)
            y_final.append(current_label)

            audio_by_class[current_label].append((y, sr))

        except Exception as e:
            print(f'[SKIPPED ORIGINAL] {fpath} -> {e}')

    # ====================================================
    # STEP 2: Augmentation block
    #    Training split only will use augment=True.
    #    Validation and test splits remain original/unaugmented.
    #    Augmentation mode: Pitch Shifting + Noise Addition
    # ====================================================
    if augment:
        print('\n   Applying target-count augmentation: PITCH SHIFTING + NOISE ADDITION...')

        current_distribution = Counter(y_final)

        for label in sorted(TARGET_COUNTS.keys()):
            current_count = current_distribution[label]
            target_count = TARGET_COUNTS[label]
            needed = target_count - current_count

            print(
                f'   {class_names[label]:<12}: '
                f'current={current_count}, target={target_count}, need={needed}'
            )

            if needed <= 0:
                continue

            if len(audio_by_class[label]) == 0:
                print(f'   No audio available for {class_names[label]}. Skipping.')
                continue

            added = 0
            audio_index = 0

            while added < needed:
                y_original, sr = audio_by_class[label][audio_index % len(audio_by_class[label])]

                try:
                    # Both augmentations: alternate noise addition and pitch shifting
                    aug_type = added % 2
                    if aug_type == 0:
                        y_aug = add_noise_awgn(y_original)
                    else:
                        y_aug = pitch_shift(y_original, sr)

                    mfcc_aug = extract_features(y_aug, sr)

                    X_mfccs.append(mfcc_aug)
                    y_final.append(label)

                    added += 1
                    audio_index += 1

                except Exception as e:
                    print(f'   [SKIPPED AUGMENTATION] {class_names[label]} -> {e}')
                    audio_index += 1

    return np.array(X_mfccs), np.array(y_final)

# %%
from sklearn.utils.class_weight import compute_class_weight

# Augmentation is applied to the training split only.
# Validation and test splits are kept original/unaugmented.
print('Processing Training Data (Pitch Shifting + Noise Addition)...')
X_train_mfcc, y_train_indices = process_data_with_augmentation(
    X_train_paths, y_train_labels, augment=True
)

print('\nProcessing Validation Data (No Augmentation)...')
X_val_mfcc, y_val_indices = process_data_with_augmentation(
    X_val_paths, y_val_labels, augment=False
)

print('\nProcessing Test Data (No Augmentation)...')
X_test_mfcc, y_test_indices = process_data_with_augmentation(
    X_test_paths, y_test_labels, augment=False
)

# Distribution summary
print('\n' + '=' * 35)
print('TRAINING DATA DISTRIBUTION (Pitch Shifting + Noise Addition):')
for label_int in sorted(Counter(y_train_indices).keys()):
    print(f' - {class_names[label_int]}: {Counter(y_train_indices)[label_int]} files')
print('=' * 35 + '\n')

# Float32 conversion
X_train_mfcc = X_train_mfcc.astype('float32')
X_val_mfcc   = X_val_mfcc.astype('float32')
X_test_mfcc  = X_test_mfcc.astype('float32')

# One-hot encoding (5 classes — identical to CNN_MFCC notebook)
y_train = to_categorical(y_train_indices, num_classes=5)
y_val   = to_categorical(y_val_indices,   num_classes=5)
y_test  = to_categorical(y_test_indices,  num_classes=5)

y_train = y_train.astype('float32')
y_val   = y_val.astype('float32')
y_test  = y_test.astype('float32')

# Class weights are computed using the final training distribution
# after the selected training augmentation has been applied.
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_indices),
    y=y_train_indices
)
class_weights = dict(enumerate(class_weights_array))

print('--- FINAL ARRAYS READY ---')
print(f'1DCNN-LSTM Input Shape (Train) : {X_train_mfcc.shape}')   # (N, 24, 13)
print(f'1DCNN-LSTM Input Shape (Val)   : {X_val_mfcc.shape}')
print(f'1DCNN-LSTM Input Shape (Test)  : {X_test_mfcc.shape}')
print(f'Label Shape (Train)            : {y_train.shape}')

print('\nClass Weights:')
for k, v in class_weights.items():
    print(f'  [{k}] {class_names[k]:<12}: {v:.4f}')
# Out:
# Processing Training Data (Pitch Shifting + Noise Addition)...
#    Processing 304 files (Augment=True)...
#
#    Applying target-count augmentation: PITCH SHIFTING + NOISE ADDITION...
#    Normal      : current=161, target=231, need=70
#    Murmur      : current=70, target=231, need=161
#    Extrasystole: current=32, target=231, need=199
#    Artifact    : current=28, target=231, need=203
#    ExtraHLS    : current=13, target=231, need=218
#
# Processing Validation Data (No Augmentation)...
#    Processing 44 files (Augment=False)...
#
# Processing Test Data (No Augmentation)...
#    Processing 88 files (Augment=False)...
#
# ===================================
# TRAINING DATA DISTRIBUTION (Pitch Shifting + Noise Addition):
#  - Normal: 231 files
#  - Murmur: 231 files
#  - Extrasystole: 231 files
#  - Artifact: 231 files
#  - ExtraHLS: 231 files
# ===================================
#
# --- FINAL ARRAYS READY ---
# 1DCNN-LSTM Input Shape (Train) : (1155, 24, 13)
# 1DCNN-LSTM Input Shape (Val)   : (44, 24, 13)
# 1DCNN-LSTM Input Shape (Test)  : (88, 24, 13)
# Label Shape (Train)            : (1155, 5)
#
# Class Weights:
#   [0] Normal      : 1.0000
#   [1] Murmur      : 1.0000
#   [2] Extrasystole: 1.0000
#   [3] Artifact    : 1.0000
#   [4] ExtraHLS    : 1.0000

# %% [markdown]
# ## Model Training — 1DCNN-LSTM Architecture

# %%
import gc
import math
import tensorflow as tf

from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D,
    MaxPooling1D,
    BatchNormalization,
    LSTM,
    Flatten,
    Dense,
    Dropout,
    Input
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import Sequence

# Clear memory
K.clear_session()
gc.collect()
print('Memory cleared.')

# Memory-safe generator 
class NumpyDataGenerator(Sequence):
    def __init__(self, X, y, batch_size=4, shuffle=True):
        self.X = X
        self.y = y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(self.X))
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.X) / self.batch_size)

    def __getitem__(self, index):
        batch_indices = self.indices[
            index * self.batch_size : (index + 1) * self.batch_size
        ]
        X_batch = self.X[batch_indices].astype('float32')
        y_batch = self.y[batch_indices].astype('float32')
        return X_batch, y_batch

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)


BATCH_SIZE = 4

train_gen = NumpyDataGenerator(X_train_mfcc, y_train, batch_size=BATCH_SIZE, shuffle=True)
val_gen   = NumpyDataGenerator(X_val_mfcc,   y_val,   batch_size=BATCH_SIZE, shuffle=False)

print('Memory-safe generators created.')


model_1dcnn_lstm = Sequential(name='1DCNN_LSTM_MFCC_Pascal_5Class_PitchShift_NoiseAddition')

model_1dcnn_lstm.add(Input(shape=(24, 13)))

# --- 1D CNN BLOCK 1 ---
model_1dcnn_lstm.add(Conv1D(
    filters=64,
    kernel_size=3,
    strides=1,
    activation='relu',
    padding='same'
))
model_1dcnn_lstm.add(BatchNormalization())
model_1dcnn_lstm.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))

# --- 1D CNN BLOCK 2 ---
model_1dcnn_lstm.add(Conv1D(
    filters=64,
    kernel_size=3,
    strides=1,
    activation='relu',
    padding='same'
))
model_1dcnn_lstm.add(BatchNormalization())
model_1dcnn_lstm.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))

# --- 1D CNN BLOCK 3 ---
model_1dcnn_lstm.add(Conv1D(
    filters=32,
    kernel_size=3,
    strides=1,
    activation='relu',
    padding='same'
))
model_1dcnn_lstm.add(BatchNormalization())
model_1dcnn_lstm.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))

# --- LSTM BLOCK ---
# return_sequences=True is used for all LSTM layers so that the output
# remains a sequence and can be passed to Flatten()
model_1dcnn_lstm.add(LSTM(256, return_sequences=True))
model_1dcnn_lstm.add(LSTM(128, return_sequences=True))
model_1dcnn_lstm.add(LSTM(64,  return_sequences=True))

# --- FLATTEN LAYER ---
model_1dcnn_lstm.add(Flatten())

# --- FULLY CONNECTED HEAD ---
model_1dcnn_lstm.add(Dense(128, activation='relu'))
model_1dcnn_lstm.add(Dense(64,  activation='relu'))
model_1dcnn_lstm.add(Dense(32,  activation='relu'))
model_1dcnn_lstm.add(Dropout(0.3))

# Output: 5 classes
model_1dcnn_lstm.add(Dense(5, activation='softmax'))

# Compile
model_1dcnn_lstm.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model_1dcnn_lstm.summary()

# Callbacks 
early_stopper = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

print('\nTraining 1DCNN-LSTM MFCC Model...')

history = model_1dcnn_lstm.fit(
    train_gen,
    epochs=50,
    validation_data=val_gen,
    callbacks=[early_stopper, reduce_lr],
    class_weight=class_weights
)
# Out:
# Memory cleared.
# Memory-safe generators created.
# Model: "1DCNN_LSTM_MFCC_Pascal_5Class_PitchShift_NoiseAddition"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 24, 64)            2560
#
#  batch_normalization (BatchN  (None, 24, 64)           256
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 12, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 12, 64)            12352
#
#  batch_normalization_1 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 6, 64)            0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 6, 32)             6176
#
#  batch_normalization_2 (Batc  (None, 6, 32)            128
#  hNormalization)
#
#  max_pooling1d_2 (MaxPooling  (None, 3, 32)            0
#  1D)
#
#  lstm (LSTM)                 (None, 3, 256)            295936
#
#  lstm_1 (LSTM)               (None, 3, 128)            197120
#
#  lstm_2 (LSTM)               (None, 3, 64)             49408
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 128)               24704
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_3 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 599,397
# Trainable params: 599,077
# Non-trainable params: 320
# _________________________________________________________________
#
# Training 1DCNN-LSTM MFCC Model...
# Epoch 1/50
# 289/289 [==============================] - 36s 40ms/step - loss: 1.5881 - accuracy: 0.2485 - val_loss: 1.3558 - val_accuracy: 0.5909 - lr: 1.0000e-04
# Epoch 2/50
# 289/289 [==============================] - 9s 30ms/step - loss: 1.4643 - accuracy: 0.3437 - val_loss: 1.0896 - val_accuracy: 0.5909 - lr: 1.0000e-04
# Epoch 3/50
# 289/289 [==============================] - 9s 30ms/step - loss: 1.3230 - accuracy: 0.4156 - val_loss: 0.9849 - val_accuracy: 0.6591 - lr: 1.0000e-04
# Epoch 4/50
# 289/289 [==============================] - 9s 31ms/step - loss: 1.2301 - accuracy: 0.4823 - val_loss: 0.9873 - val_accuracy: 0.7045 - lr: 1.0000e-04
# Epoch 5/50
# 289/289 [==============================] - 9s 29ms/step - loss: 1.1898 - accuracy: 0.4727 - val_loss: 0.9593 - val_accuracy: 0.6136 - lr: 1.0000e-04
# Epoch 6/50
# 289/289 [==============================] - 9s 30ms/step - loss: 1.1097 - accuracy: 0.5359 - val_loss: 0.9163 - val_accuracy: 0.6818 - lr: 1.0000e-04
# Epoch 7/50
# 289/289 [==============================] - 9s 30ms/step - loss: 1.0837 - accuracy: 0.5446 - val_loss: 1.0149 - val_accuracy: 0.5909 - lr: 1.0000e-04
# Epoch 8/50
# 289/289 [==============================] - 8s 29ms/step - loss: 1.0486 - accuracy: 0.5758 - val_loss: 1.0098 - val_accuracy: 0.6136 - lr: 1.0000e-04
# Epoch 9/50
# 288/289 [============================>.] - ETA: 0s - loss: 1.0214 - accuracy: 0.5760
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 289/289 [==============================] - 8s 28ms/step - loss: 1.0237 - accuracy: 0.5749 - val_loss: 0.9281 - val_accuracy: 0.6591 - lr: 1.0000e-04
# Epoch 10/50
# 289/289 [==============================] - 8s 28ms/step - loss: 0.9261 - accuracy: 0.6390 - val_loss: 0.8499 - val_accuracy: 0.6591 - lr: 5.0000e-05
# Epoch 11/50
# 289/289 [==============================] - 8s 28ms/step - loss: 0.9075 - accuracy: 0.6407 - val_loss: 0.8497 - val_accuracy: 0.6818 - lr: 5.0000e-05
# Epoch 12/50
# 289/289 [==============================] - 8s 29ms/step - loss: 0.8755 - accuracy: 0.6554 - val_loss: 0.8570 - val_accuracy: 0.6591 - lr: 5.0000e-05
# Epoch 13/50
# 289/289 [==============================] - 8s 28ms/step - loss: 0.8642 - accuracy: 0.6571 - val_loss: 0.8352 - val_accuracy: 0.6818 - lr: 5.0000e-05
# Epoch 14/50
# 289/289 [==============================] - 8s 27ms/step - loss: 0.8534 - accuracy: 0.6667 - val_loss: 0.8573 - val_accuracy: 0.6591 - lr: 5.0000e-05
# Epoch 15/50
# 289/289 [==============================] - 8s 28ms/step - loss: 0.8351 - accuracy: 0.6701 - val_loss: 0.8069 - val_accuracy: 0.7045 - lr: 5.0000e-05
# Epoch 16/50
# 289/289 [==============================] - 8s 28ms/step - loss: 0.8056 - accuracy: 0.6892 - val_loss: 0.8315 - val_accuracy: 0.6818 - lr: 5.0000e-05
# Epoch 17/50
# 289/289 [==============================] - 8s 27ms/step - loss: 0.7772 - accuracy: 0.7065 - val_loss: 0.8113 - val_accuracy: 0.6818 - lr: 5.0000e-05
# Epoch 18/50
# 289/289 [==============================] - ETA: 0s - loss: 0.8039 - accuracy: 0.6978
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 289/289 [==============================] - 9s 29ms/step - loss: 0.8039 - accuracy: 0.6978 - val_loss: 0.8704 - val_accuracy: 0.6591 - lr: 5.0000e-05
# Epoch 19/50
# 289/289 [==============================] - 8s 28ms/step - loss: 0.7365 - accuracy: 0.7074 - val_loss: 0.7764 - val_accuracy: 0.7045 - lr: 2.5000e-05
# Epoch 20/50
# 289/289 [==============================] - 8s 29ms/step - loss: 0.7336 - accuracy: 0.7212 - val_loss: 0.7736 - val_accuracy: 0.7273 - lr: 2.5000e-05
# Epoch 21/50
# 289/289 [==============================] - 9s 30ms/step - loss: 0.7461 - accuracy: 0.7143 - val_loss: 0.7826 - val_accuracy: 0.7045 - lr: 2.5000e-05
# Epoch 22/50
# 289/289 [==============================] - 9s 30ms/step - loss: 0.7478 - accuracy: 0.7065 - val_loss: 0.8394 - val_accuracy: 0.6818 - lr: 2.5000e-05
# Epoch 23/50
# 288/289 [============================>.] - ETA: 0s - loss: 0.7170 - accuracy: 0.7237
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 289/289 [==============================] - 8s 29ms/step - loss: 0.7161 - accuracy: 0.7238 - val_loss: 0.7861 - val_accuracy: 0.6818 - lr: 2.5000e-05
# Epoch 24/50
# 289/289 [==============================] - 9s 29ms/step - loss: 0.7129 - accuracy: 0.7351 - val_loss: 0.8014 - val_accuracy: 0.7045 - lr: 1.2500e-05
# Epoch 25/50
# 289/289 [==============================] - 8s 29ms/step - loss: 0.7132 - accuracy: 0.7342 - val_loss: 0.7906 - val_accuracy: 0.7045 - lr: 1.2500e-05

# %%
import gc
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model

model_path = '1dcnn_lstm_mfcc_pascal_5class_NoAug.h5'

print('Current directory:', os.getcwd())

model_1dcnn_lstm.save(model_path)
print('Model saved successfully!')

K.clear_session()
gc.collect()
print('Memory cleared after training.')

model_1dcnn_lstm = load_model(model_path)
print('Model reloaded successfully!')
# Out:
# Current directory: C:\Users\emirh\Downloads\FYP2\Models_PASCAL\MFCC_As_Input\Hybrid_Model\Models_AftrChanges\CNN-LSTM\Count
# Model saved successfully!
# Memory cleared after training.
# Model reloaded successfully!

# %% [markdown]
# ## Training Curves

# %%
if 'history' in locals():
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()
else:
    print('No history found. Please train the model first.')

# %% [markdown]
# ## Classification Output
#
# > Evaluation function identical to `DeepLearningModel_VGG19_MFCC_Test1.ipynb`.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Class labels (identical to VGG19 notebook)
classes = ['Normal', 'Murmur', 'ExtraSys', 'Artifact', 'ExtraHLS']

def evaluate_and_plot_manual(model, X, y, set_name, batch_size=1):
    print(f"\n{'='*20} {set_name.upper()} RESULTS {'='*20}")

    y_true_all = []
    y_pred_all = []

    total_samples = len(X)

    for start in range(0, total_samples, batch_size):
        end = min(start + batch_size, total_samples)

        X_batch = X[start:end].astype('float32')
        y_batch = y[start:end]

        pred_batch = model.predict(X_batch, verbose=0)

        y_pred_all.extend(np.argmax(pred_batch, axis=1))
        y_true_all.extend(np.argmax(y_batch, axis=1))

    y_true_all = np.array(y_true_all)
    y_pred_all = np.array(y_pred_all)

    acc = accuracy_score(y_true_all, y_pred_all)
    print(f'{set_name} Accuracy: {acc * 100:.2f}%')

    cm = confusion_matrix(y_true_all, y_pred_all)

    plt.figure(figsize=(6, 5))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Blues',
        xticklabels=classes,
        yticklabels=classes
    )
    plt.title(f'Confusion Matrix ({set_name})')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()

    print(classification_report(
        y_true_all,
        y_pred_all,
        target_names=classes,
        labels=[0, 1, 2, 3, 4],
        zero_division=0
    ))

# %%
evaluate_and_plot_manual(model_1dcnn_lstm, X_train_mfcc, y_train, 'Training Set', batch_size=4)
# Out:
# ==================== TRAINING SET RESULTS ====================
# Training Set Accuracy: 71.52%
#               precision    recall  f1-score   support
#
#       Normal       0.61      0.68      0.64       231
#       Murmur       0.79      0.48      0.59       231
#     ExtraSys       0.65      0.68      0.67       231
#     Artifact       0.87      0.83      0.85       231
#     ExtraHLS       0.70      0.91      0.79       231
#
#     accuracy                           0.72      1155
#    macro avg       0.73      0.72      0.71      1155
# weighted avg       0.73      0.72      0.71      1155

# %%
evaluate_and_plot_manual(model_1dcnn_lstm, X_val_mfcc,   y_val,   'Validation Set', batch_size=4)
# Out:
# ==================== VALIDATION SET RESULTS ====================
# Validation Set Accuracy: 72.73%
#               precision    recall  f1-score   support
#
#       Normal       0.76      0.96      0.85        23
#       Murmur       0.86      0.60      0.71        10
#     ExtraSys       0.00      0.00      0.00         5
#     Artifact       0.75      0.75      0.75         4
#     ExtraHLS       0.33      0.50      0.40         2
#
#     accuracy                           0.73        44
#    macro avg       0.54      0.56      0.54        44
# weighted avg       0.67      0.73      0.69        44

# %%
evaluate_and_plot_manual(model_1dcnn_lstm, X_test_mfcc,  y_test,  'Test Set', batch_size=4)
# Out:
# ==================== TEST SET RESULTS ====================
# Test Set Accuracy: 67.05%
#               precision    recall  f1-score   support
#
#       Normal       0.74      0.89      0.81        47
#       Murmur       0.56      0.45      0.50        20
#     ExtraSys       0.00      0.00      0.00         9
#     Artifact       0.67      0.75      0.71         8
#     ExtraHLS       0.40      0.50      0.44         4
#
#     accuracy                           0.67        88
#    macro avg       0.47      0.52      0.49        88
# weighted avg       0.60      0.67      0.63        88
